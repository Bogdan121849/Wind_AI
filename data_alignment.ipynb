# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
MET_forecast = pd.read_parquet("WindAi/met_forecast .parquet")
MET_nowcast = pd.read_parquet("WindAi/met_nowcast.parquet")
Power_data = pd.read_parquet("WindAi/wind_power_per_bidzone.parquet")
Meta_data = pd.read_csv("WindAi/windparks_bidzone.csv")

# %% [markdown]
# MET_forecast

# %%
MET_forecast.head(10)
# Out:
#             sid            time_ref                time  lt  ws10m_00  \
# 0  Engerfjellet 2020-02-15 12:00:00 2020-02-15 12:00:00   0  2.096957
# 1  Engerfjellet 2020-02-15 12:00:00 2020-02-15 13:00:00   1  3.449402
# 2  Engerfjellet 2020-02-15 12:00:00 2020-02-15 14:00:00   2  3.348926
# 3  Engerfjellet 2020-02-15 12:00:00 2020-02-15 15:00:00   3  3.095971
# 4  Engerfjellet 2020-02-15 12:00:00 2020-02-15 16:00:00   4  2.821545
# 5  Engerfjellet 2020-02-15 12:00:00 2020-02-15 17:00:00   5  4.114142
# 6  Engerfjellet 2020-02-15 12:00:00 2020-02-15 18:00:00   6  3.790050
# 7  Engerfjellet 2020-02-15 12:00:00 2020-02-15 19:00:00   7  4.555474
# 8  Engerfjellet 2020-02-15 12:00:00 2020-02-15 20:00:00   8  5.318298
# 9  Engerfjellet 2020-02-15 12:00:00 2020-02-15 21:00:00   9  6.120933
#
#    ws10m_01  ws10m_02  ws10m_03  ws10m_04  ws10m_05  ...    g10m_05  \
# 0  2.110652  2.304629  1.942044  1.447011  2.288181  ...   6.918935
# ...

# %%
times_forecast = set(MET_forecast["time"].unique())

# %%
MET_forecast.loc[MET_forecast.sid == "Engerfjellet"]
# Out:
#                   sid            time_ref                time  lt  ws10m_00  \
# 0        Engerfjellet 2020-02-15 12:00:00 2020-02-15 12:00:00   0  2.096957
# 1        Engerfjellet 2020-02-15 12:00:00 2020-02-15 13:00:00   1  3.449402
# 2        Engerfjellet 2020-02-15 12:00:00 2020-02-15 14:00:00   2  3.348926
# 3        Engerfjellet 2020-02-15 12:00:00 2020-02-15 15:00:00   3  3.095971
# 4        Engerfjellet 2020-02-15 12:00:00 2020-02-15 16:00:00   4  2.821545
# ...               ...                 ...                 ...  ..       ...
# 6843247  Engerfjellet 2025-03-15 09:00:00 2025-03-18 01:00:00  64  1.870437
# 6843248  Engerfjellet 2025-03-16 09:00:00 2025-03-19 01:00:00  64  2.275855
# 6843249  Engerfjellet 2025-03-22 09:00:00 2025-03-25 01:00:00  64  4.909470
# 6843250  Engerfjellet 2025-03-23 09:00:00 2025-03-26 01:00:00  64  2.586512
# 6843251  Engerfjellet 2025-03-24 09:00:00 2025-03-27 01:00:00  64  1.823800
#
# ...

# %%
len(MET_forecast["time"].unique())
# Out:
# 44555

# %% [markdown]
# MET_nowcast

# %%
MET_nowcast.head(10)
# Out:
#                      air_temperature_2m  air_pressure_at_sea_level  \
# time
# 2020-01-01 00:00:00          276.363831              100703.859375
# 2020-01-01 01:00:00          276.951080              100595.609375
# 2020-01-01 02:00:00          277.113007              100526.656250
# 2020-01-01 03:00:00          277.259033              100408.359375
# 2020-01-01 04:00:00          277.229248              100421.062500
# 2020-01-01 05:00:00          277.192139              100427.195312
# 2020-01-01 06:00:00          277.338379              100457.250000
# 2020-01-01 07:00:00          277.468933              100486.578125
# 2020-01-01 08:00:00          277.481262              100529.734375
# 2020-01-01 09:00:00          277.737762              100510.437500
#
#                      relative_humidity_2m  precipitation_amount  \
# time
# 2020-01-01 00:00:00              0.966131              3.147963
# 2020-01-01 01:00:00              0.972677              3.636308
# ...

# %%
times_nowcast = set(MET_nowcast.index.unique())

# %% [markdown]
# Power_data

# %%
Power_data.head(10)
# Out:
#                      ELSPOT NO1  ELSPOT NO2  ELSPOT NO3  ELSPOT NO4
# 2020-01-01 00:00:00  149.285262  434.753864  497.143482  152.830002
# 2020-01-01 01:00:00  152.634024  395.572485  471.916899  144.440344
# 2020-01-01 02:00:00  151.163256  355.408523  399.325698  143.960894
# 2020-01-01 03:00:00  150.223341  375.316902  367.662849  134.310523
# 2020-01-01 04:00:00  157.415142  412.949107  399.627337   88.573315
# 2020-01-01 05:00:00  151.640429  409.595038  446.307181   72.441640
# 2020-01-01 06:00:00  144.248918  398.444034  483.106530   61.640700
# 2020-01-01 07:00:00  131.882442  413.906336  508.145019   60.053104
# 2020-01-01 08:00:00  147.393227  384.363898  516.745855   59.939813
# 2020-01-01 09:00:00  146.475636  379.636768  550.368464   56.989839

# %%
Power_data.shape
# Out:
# (46011, 4)

# %%
Power_data_long = Power_data.reset_index().melt(
    id_vars="index", 
    var_name="bidding_area", 
    value_name="power_MW"
).rename(columns={"index": "time"})

# %%
Power_data_long.head(10)
# Out:
#                  time bidding_area    power_MW
# 0 2020-01-01 00:00:00   ELSPOT NO1  149.285262
# 1 2020-01-01 01:00:00   ELSPOT NO1  152.634024
# 2 2020-01-01 02:00:00   ELSPOT NO1  151.163256
# 3 2020-01-01 03:00:00   ELSPOT NO1  150.223341
# 4 2020-01-01 04:00:00   ELSPOT NO1  157.415142
# 5 2020-01-01 05:00:00   ELSPOT NO1  151.640429
# 6 2020-01-01 06:00:00   ELSPOT NO1  144.248918
# 7 2020-01-01 07:00:00   ELSPOT NO1  131.882442
# 8 2020-01-01 08:00:00   ELSPOT NO1  147.393227
# 9 2020-01-01 09:00:00   ELSPOT NO1  146.475636

# %%
times_power = set(Power_data_long["time"].unique())
difference_forecast = times_forecast - times_power
print(f"Hours in forecast not in power: {len(difference_forecast)}")

difference_power = times_power - times_forecast
print(f"Hours in power not in forecast: {len(difference_power)}")

difference_now = times_nowcast - times_forecast
print(f"Hours in nowcast not in forecast: {len(difference_now)}")
# Out:
# Hours in forecast not in power: 18
# Hours in power not in forecast: 1474
# Hours in nowcast not in forecast: 46007

# %%
Power_data_long.shape
# Out:
# (184044, 3)

# %%
Power_data_long.loc[Power_data_long.bidding_area == "ELSPOT NO1"]
# Out:
#                      time bidding_area    power_MW
# 0     2020-01-01 00:00:00   ELSPOT NO1  149.285262
# 1     2020-01-01 01:00:00   ELSPOT NO1  152.634024
# 2     2020-01-01 02:00:00   ELSPOT NO1  151.163256
# 3     2020-01-01 03:00:00   ELSPOT NO1  150.223341
# 4     2020-01-01 04:00:00   ELSPOT NO1  157.415142
# ...                   ...          ...         ...
# 46006 2025-04-03 04:00:00   ELSPOT NO1  201.955371
# 46007 2025-04-03 05:00:00   ELSPOT NO1  192.814220
# 46008 2025-04-03 06:00:00   ELSPOT NO1  167.243268
# 46009 2025-04-03 07:00:00   ELSPOT NO1  149.052714
# 46010 2025-04-03 08:00:00   ELSPOT NO1   74.623448
#
# [46011 rows x 3 columns]

# %%
Power_data_long["bidding_area"].value_counts()
# Out:
# ELSPOT NO2    46011
# ELSPOT NO3    46011
# ELSPOT NO4    46011
# ELSPOT NO1    46011
# Name: bidding_area, dtype: int64

# %%
Power_data_long.groupby("bidding_area")["time"].agg(["min", "max", "count"])
# Out:
#                     min                 max  count
# bidding_area
# ELSPOT NO1   2020-01-01 2025-04-03 08:00:00  46011
# ELSPOT NO2   2020-01-01 2025-04-03 08:00:00  46011
# ELSPOT NO3   2020-01-01 2025-04-03 08:00:00  46011
# ELSPOT NO4   2020-01-01 2025-04-03 08:00:00  46011

# %%
times = Power_data_long["time"].drop_duplicates()
times.shape
# Out:
# (46011,)

# %% [markdown]
# Meta_data

# %%
Meta_data.head(10)
# Out:
#   bidding_area    substation_name  operating_power_max       prod_start_new  \
# 0   ELSPOT NO1       Engerfjellet                 52.8  2022-09-19 13:00:00
# 1   ELSPOT NO1       Hån Vindpark                 21.0  2022-10-26 22:00:00
# 2   ELSPOT NO1         Kjølberget                 55.9  2020-07-07 09:00:00
# 3   ELSPOT NO1    Marker Vindpark                 54.0  2020-01-01 00:00:00
# 4   ELSPOT NO1          Raskiftet                111.6  2020-01-01 00:00:00
# 5   ELSPOT NO1         Songkjølen                110.4  2021-08-24 10:00:00
# 6   ELSPOT NO2  Bjerk_VK Vindpark                301.0  2020-01-01 00:00:00
# 7   ELSPOT NO2  Bjerk_VK Vindpark                301.0  2020-01-01 00:00:00
# 8   ELSPOT NO2    Buheii Vindpark                 80.4  2021-06-09 08:00:00
# 9   ELSPOT NO2   Egersund Vindkrv                112.2  2020-01-01 00:00:00
#
#            eic_code
# 0  50WP00000002158R
# 1  50WP000000022251
# 2  50WP00000002085S
# 3  50WP00000002048Y
# 4  50WP00000001718K
# ...

# %%
Meta_data.groupby("bidding_area")["substation_name"].apply(list).reset_index()
# Out:
#   bidding_area                                    substation_name
# 0   ELSPOT NO1  [Engerfjellet, Hån Vindpark, Kjølberget, Marke...
# 1   ELSPOT NO2  [Bjerk_VK Vindpark, Bjerk_VK Vindpark, Buheii ...
# 2   ELSPOT NO3  [Bessakerfjellet, Einarsdalen, Frøya Vindpark,...
# 3   ELSPOT NO4  [Dønnesfjord Vind, Fakken, Hamnefjell, Havøyga...

# %%
Meta_data["bidding_area"].value_counts()
# Out:
# ELSPOT NO3    28
# ELSPOT NO2    27
# ELSPOT NO4    15
# ELSPOT NO1     6
# Name: bidding_area, dtype: int64

# %%
Meta_data.shape
# Out:
# (76, 5)

# %% [markdown]
# Meta_with_power

# %%
bidding_times = Power_data_long[["time", "bidding_area", "power_MW"]]

meta_with_power = Meta_data.merge(bidding_times, on="bidding_area", how="left")

# %%
meta_with_power.head(10)
# Out:
#   bidding_area substation_name  operating_power_max       prod_start_new  \
# 0   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 1   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 2   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 3   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 4   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 5   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 6   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 7   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 8   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 9   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
#
#            eic_code                time    power_MW
# 0  50WP00000002158R 2020-01-01 00:00:00  149.285262
# 1  50WP00000002158R 2020-01-01 01:00:00  152.634024
# ...

# %%
meta_with_power.describe().transpose()
# Out:
#                          count        mean         std  min         25%  \
# operating_power_max  3496836.0   78.489474   75.501338  0.4   12.600000
# power_MW             3496737.0  447.166095  404.516611  0.0  122.330702
#
#                            50%         75%          max
# operating_power_max   53.40000  124.700000   301.000000
# power_MW             320.99224  674.260631  1921.052333

# %%
meta_with_power.shape
# Out:
# (3496836, 7)

# %% [markdown]
# Meta_with_power_forecast

# %%
meta_with_power_forecast = meta_with_power.merge(
    MET_forecast,
    left_on=["substation_name", "time"],
    right_on=["sid", "time"],
    how="left"
)

# %%
meta_with_power_forecast = meta_with_power_forecast.drop(columns=["sid"])
meta_with_power_forecast.head(10)
# Out:
#   bidding_area substation_name  operating_power_max       prod_start_new  \
# 0   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 1   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 2   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 3   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 4   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 5   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 6   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 7   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 8   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 9   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
#
#            eic_code                time    power_MW time_ref  lt  ws10m_00  \
# 0  50WP00000002158R 2020-01-01 00:00:00  149.285262      NaT NaN       NaN
# ...

# %%
meta_with_power_forecast.shape
# Out:
# (8264466, 99)

# %% [markdown]
# meta_with_power_forecast_now

# %%
meta_with_power_forecast_now = meta_with_power_forecast.merge(
    MET_nowcast,
    left_on=["substation_name", "time"],
    right_on=["windpark", "time"],
    how="left"
)

# %%
meta_with_power_forecast_now = meta_with_power_forecast_now.drop(columns=["windpark"])
meta_with_power_forecast_now.head(10)
# Out:
#   bidding_area substation_name  operating_power_max       prod_start_new  \
# 0   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 1   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 2   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 3   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 4   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 5   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 6   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 7   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 8   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
# 9   ELSPOT NO1    Engerfjellet                 52.8  2022-09-19 13:00:00
#
#            eic_code                time    power_MW time_ref  lt  ws10m_00  \
# 0  50WP00000002158R 2020-01-01 00:00:00  149.285262      NaT NaN       NaN
# ...

# %%
print(f"Time range: {MET_forecast['time'].min()} to {MET_forecast['time'].max()}")
print(f"Time range: {MET_nowcast.index.min()} to {MET_nowcast.index.max()}")
print(f"Time range: {Power_data_long['time'].min()} to {Power_data_long['time'].max()}")
# Out:
# Time range: 2020-02-15 12:00:00 to 2025-03-27 01:00:00
# Time range: 2020-01-01 00:00:00 to 2025-03-31 23:00:00
# Time range: 2020-01-01 00:00:00 to 2025-04-03 08:00:00

# %%
meta_with_power_forecast_now.isna().sum()
# Out:
# bidding_area                      0
# substation_name                   0
# operating_power_max               0
# prod_start_new                    0
# eic_code                          0
#                               ...
# air_pressure_at_sea_level    508386
# relative_humidity_2m         508386
# precipitation_amount         508386
# wind_speed_10m               508386
# wind_direction_10m           508386
# Length: 105, dtype: int64

# %%
meta_with_power_forecast_now.sum()

# %%
meta_with_power_forecast_now.shape
# Out:
# (8264466, 105)

# %%
meta_with_power_forecast_now.to_parquet("WindAi/model_dataset_raw.parquet", index=False)

# %%
baris = pd.read_parquet("model_dataset.parquet")
baris.head(10)
# Out:
#          zone                valid_time   ws_mean  ws_spread    ws_now  \
# 0  ELSPOT NO1 2020-02-17 12:00:00+00:00  8.185420   0.722786  8.038021
# 1  ELSPOT NO1 2020-02-17 13:00:00+00:00  8.389066   0.627843  8.289558
# 2  ELSPOT NO1 2020-02-17 14:00:00+00:00  8.331227   0.823593  8.846123
# 3  ELSPOT NO1 2020-02-17 15:00:00+00:00  8.148322   1.030787  9.047679
# 4  ELSPOT NO1 2020-02-17 16:00:00+00:00  7.768180   1.065021  8.844782
# 5  ELSPOT NO1 2020-02-17 17:00:00+00:00  7.453814   1.266565  9.152249
# 6  ELSPOT NO1 2020-02-17 18:00:00+00:00  7.175088   1.348435  8.329453
# 7  ELSPOT NO1 2020-02-17 19:00:00+00:00  6.940632   1.240503  7.006623
# 8  ELSPOT NO1 2020-02-17 20:00:00+00:00  6.642488   1.124397  6.234801
# 9  ELSPOT NO1 2020-02-17 21:00:00+00:00  6.501365   1.110936  5.181411
#
#       t2m_now     p_slp_now    rh_now    tp_now       power
# 0  275.437264  97791.388541  0.857981  0.006335  133.619331
# 1  275.881535  97764.267377  0.849889  0.000290  144.005562
# ...

# %%
baris.shape
# Out:
# (106330, 10)
